# %% [markdown]
# # 07 - Final Experiments
#
# ## Objective
# Run systematic experiments to compare RL algorithms for cloud autoscaling.
#
# ## Experiment Grid
# 1. **Algorithms**: Q-Learning, SARSA, Threshold Baseline
# 2. **Hyperparameters**: Learning rate, discount factor, exploration rate
# 3. **Workload Patterns**: Steady, bursty, periodic
# 4. **Metrics**: Total reward, SLA violations, cost, convergence speed
#
# ## Outputs
# - Performance comparison tables
# - Learning curves
# - Policy visualizations

# %%
# Standard imports
import sys
from pathlib import Path
from itertools import product

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / "src"))

# Import our modules
from agent.cloud_autoscaling_env import CloudAutoscalingEnv
from agent.q_learning_agent import QLearningAgent
from agent.sarsa_agent import SARSAAgent
from agent.baseline_policies import *
from agent.main_experiments import run_experiment_grid

# Plot settings
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

# Reproducibility
np.random.seed(42)

print("✓ Setup complete!")

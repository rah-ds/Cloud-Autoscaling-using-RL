# %% [markdown]
# # 06 - Hybrid Experiments
#
# ## Objective
# Explore hybrid approaches that combine:
# 1. **Threshold-based policies** with RL fine-tuning
# 2. **Model-based RL** with workload prediction
# 3. **Ensemble methods** combining multiple agents
#
# ## Experiments
# - [ ] Threshold + Q-Learning hybrid
# - [ ] SARSA with adaptive exploration
# - [ ] Workload forecasting integration

# %%
# Standard imports
import sys
from pathlib import Path

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Add src to path
sys.path.insert(0, str(Path.cwd().parent / "src"))

# Import our modules
from agent.cloud_autoscaling_env import CloudAutoscalingEnv
from agent.q_learning_agent import QLearningAgent
from agent.sarsa_agent import SARSAAgent
from agent.baseline_policies import *

# Plot settings
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (12, 6)

print("✓ Setup complete!")
